# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
raw_image = np.load('weights/test_df.npy')

# %%
raw_image.shape
# Out:
# (4927, 64, 64, 1)

# %%
imshow(raw_image[0],cmap='gray')

# %%
imshow(raw_image[1],cmap='gray')

# %%
imshow(raw_image[2],cmap='gray')

# %%
imshow(raw_image[3],cmap='gray')

# %%
imshow(raw_image[4],cmap='gray')

# %%
imshow(raw_image[5],cmap='gray')

# %%
imshow(raw_image[6],cmap='gray')

# %%
imshow(raw_image[7],cmap='gray')

# %%
imshow(raw_image[8],cmap='gray')
