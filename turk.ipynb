# %%
# !pip install mahotas
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import shutil
import matplotlib.patches as patches
from PIL import Image
import re
from deep_lesion.models.vae import LesionVAE
from deep_lesion.models.contrastive import LesionSimCLR

# %%
test_data = np.load('/Users/user/Downloads/raw_new.npy')
plt.imshow(test_data[9], cmap='gray')

# %%
simclr = LesionSimCLR.load_from_checkpoint('/Users/user/contrastive.ckpt')
