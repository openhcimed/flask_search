# %%
from google.colab import drive
drive.mount('/content/gdrive/')
#from tensorflow.python.client import device_lib
#device_lib.list_local_devices()
# Out:
# Mounted at /content/gdrive/

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D,MaxPool2D ,UpSampling2D, Flatten, Input
#from keras.optimizers import SGD, Adam, Adadelta, Adagrad
from keras import backend as K
from numpy import load
from keras.preprocessing import image
import keras, keras.layers as L, keras.backend as K
keras.backend.set_image_data_format('channels_last')

# %%
test_images = sorted(os.listdir('/content/gdrive/MyDrive/lesion/crop_image/test_crop/'))
test_images
# Out:
# ['cropped_test_0.png',
#  'cropped_test_1.png',
#  'cropped_test_10.png',
#  'cropped_test_100.png',
#  'cropped_test_1000.png',
#  'cropped_test_1001.png',
#  'cropped_test_1002.png',
#  'cropped_test_1003.png',
#  'cropped_test_1004.png',
#  'cropped_test_1005.png',
#  'cropped_test_1006.png',
#  'cropped_test_1007.png',
#  'cropped_test_1008.png',
#  'cropped_test_1009.png',
#  'cropped_test_101.png',
#  'cropped_test_1010.png',
#  'cropped_test_1011.png',
#  'cropped_test_1012.png',
#  'cropped_test_1013.png',
#  'cropped_test_1014.png',
#  'cropped_test_1015.png',
#  'cropped_test_1016.png',
#  'cropped_test_1017.png',
#  'cropped_test_1018.png',
#  'cropped_test_1019.png',
#  'cropped_test_102.png',
#  'cropped_test_1020.png',
#  'cropped_test_1021.png',
#  'cropped_test_1022.png',
#  'cropped_test_1023.png',
#  'cropped_test_1024.png',
#  'cropped_test_1025.png',
#  'cropped_test_1026.png',
#  'cropped_test_1027.png',
#  'cropped_test_1028.png',
#  'cropped_test_1029.png',
#  'cropped_test_103.png',
#  'cropped_test_1030.png',
#  'cropped_test_1031.png',
#  'cropped_test_1032.png',
#  'cropped_test_1033.png',
#  'cropped_test_1034.png',
#  'cropped_test_1035.png',
#  'cropped_test_1036.png',
#  'cropped_test_1037.png',
#  'cropped_test_1038.png',
#  'cropped_test_1039.png',
#  'cropped_test_104.png',
#  'cropped_test_1040.png',
#  'cropped_test_1041.png',
#  'cropped_test_1042.png',
#  'cropped_test_1043.png',
#  'cropped_test_1044.png',
#  'cropped_test_1045.png',
#  'cropped_test_1046.png',
#  'cropped_test_1047.png',
#  'cropped_test_1048.png',
#  'cropped_test_1049.png',
#  'cropped_test_105.png',
#  'cropped_test_1050.png',
#  'cropped_test_1051.png',
#  'cropped_test_1052.png',
#  'cropped_test_1053.png',
#  'cropped_test_1054.png',
#  'cropped_test_1055.png',
#  'cropped_test_1056.png',
#  'cropped_test_1057.png',
#  'cropped_test_1058.png',
#  'cropped_test_1059.png',
#  'cropped_test_106.png',
#  'cropped_test_1060.png',
#  'cropped_test_1061.png',
#  'cropped_test_1062.png',
#  'cropped_test_1063.png',
#  'cropped_test_1064.png',
#  'cropped_test_1065.png',
#  'cropped_test_1066.png',
#  'cropped_test_1067.png',
#  'cropped_test_1068.png',
#  'cropped_test_1069.png',
#  'cropped_test_107.png',
#  'cropped_test_1070.png',
#  'cropped_test_1071.png',
#  'cropped_test_1072.png',
#  'cropped_test_1073.png',
#  'cropped_test_1074.png',
#  'cropped_test_1075.png',
#  'cropped_test_1076.png',
#  'cropped_test_1077.png',
#  'cropped_test_1078.png',
#  'cropped_test_1079.png',
#  'cropped_test_108.png',
#  'cropped_test_1080.png',
#  'cropped_test_1081.png',
#  'cropped_test_1082.png',
#  'cropped_test_1083.png',
#  'cropped_test_1084.png',
#  'cropped_test_1085.png',
#  'cropped_test_1086.png',
#  'cropped_test_1087.png',
#  'cropped_test_1088.png',
#  'cropped_test_1089.png',
#  'cropped_test_109.png',
#  'cropped_test_1090.png',
#  'cropped_test_1091.png',
#  'cropped_test_1092.png',
#  'cropped_test_1093.png',
#  'cropped_test_1094.png',
#  'cropped_test_1095.png',
#  'cropped_test_1096.png',
#  'cropped_test_1097.png',
#  'cropped_test_1098.png',
#  'cropped_test_1099.png',
#  'cropped_test_11.png',
#  'cropped_test_110.png',
#  'cropped_test_1100.png',
#  'cropped_test_1101.png',
#  'cropped_test_1102.png',
#  'cropped_test_1103.png',
#  'cropped_test_1104.png',
#  'cropped_test_1105.png',
#  'cropped_test_1106.png',
#  'cropped_test_1107.png',
#  'cropped_test_1108.png',
#  'cropped_test_1109.png',
#  'cropped_test_111.png',
#  'cropped_test_1110.png',
#  'cropped_test_1111.png',
#  'cropped_test_1112.png',
#  'cropped_test_1113.png',
#  'cropped_test_1114.png',
#  'cropped_test_1115.png',
#  'cropped_test_1116.png',
#  'cropped_test_1117.png',
#  'cropped_test_1118.png',
#  'cropped_test_1119.png',
#  'cropped_test_112.png',
#  'cropped_test_1120.png',
#  'cropped_test_1121.png',
#  'cropped_test_1122.png',
#  'cropped_test_1123.png',
#  'cropped_test_1124.png',
#  'cropped_test_1125.png',
#  'cropped_test_1126.png',
#  'cropped_test_1127.png',
#  'cropped_test_1128.png',
#  'cropped_test_1129.png',
#  'cropped_test_113.png',
#  'cropped_test_1130.png',
#  'cropped_test_1131.png',
#  'cropped_test_1132.png',
#  'cropped_test_1133.png',
#  'cropped_test_1134.png',
#  'cropped_test_1135.png',
#  'cropped_test_1136.png',
#  'cropped_test_1137.png',
#  'cropped_test_1138.png',
#  'cropped_test_1139.png',
#  'cropped_test_114.png',
#  'cropped_test_1140.png',
#  'cropped_test_1141.png',
#  'cropped_test_1142.png',
#  'cropped_test_1143.png',
#  'cropped_test_1144.png',
#  'cropped_test_1145.png',
#  'cropped_test_1146.png',
#  'cropped_test_1147.png',
#  'cropped_test_1148.png',
#  'cropped_test_1149.png',
#  'cropped_test_115.png',
#  'cropped_test_1150.png',
#  'cropped_test_1151.png',
#  'cropped_test_1152.png',
#  'cropped_test_1153.png',
#  'cropped_test_1154.png',
#  'cropped_test_1155.png',
#  'cropped_test_1156.png',
#  'cropped_test_1157.png',
#  'cropped_test_1158.png',
#  'cropped_test_1159.png',
#  'cropped_test_116.png',
#  'cropped_test_1160.png',
#  'cropped_test_1161.png',
#  'cropped_test_1162.png',
#  'cropped_test_1163.png',
#  'cropped_test_1164.png',
#  'cropped_test_1165.png',
#  'cropped_test_1166.png',
#  'cropped_test_1167.png',
#  'cropped_test_1168.png',
#  'cropped_test_1169.png',
#  'cropped_test_117.png',
#  'cropped_test_1170.png',
#  'cropped_test_1171.png',
#  'cropped_test_1172.png',
#  'cropped_test_1173.png',
#  'cropped_test_1174.png',
#  'cropped_test_1175.png',
#  'cropped_test_1176.png',
#  'cropped_test_1177.png',
#  'cropped_test_1178.png',
#  'cropped_test_1179.png',
#  'cropped_test_118.png',
#  'cropped_test_1180.png',
#  'cropped_test_1181.png',
#  'cropped_test_1182.png',
#  'cropped_test_1183.png',
#  'cropped_test_1184.png',
#  'cropped_test_1185.png',
#  'cropped_test_1186.png',
#  'cropped_test_1187.png',
#  'cropped_test_1188.png',
#  'cropped_test_1189.png',
#  'cropped_test_119.png',
#  'cropped_test_1190.png',
#  'cropped_test_1191.png',
#  'cropped_test_1192.png',
#  'cropped_test_1193.png',
#  'cropped_test_1194.png',
#  'cropped_test_1195.png',
#  'cropped_test_1196.png',
#  'cropped_test_1197.png',
#  'cropped_test_1198.png',
#  'cropped_test_1199.png',
#  'cropped_test_12.png',
#  'cropped_test_120.png',
#  'cropped_test_1200.png',
#  'cropped_test_1201.png',
#  'cropped_test_1202.png',
#  'cropped_test_1203.png',
#  'cropped_test_1204.png',
#  'cropped_test_1205.png',
#  'cropped_test_1206.png',
#  'cropped_test_1207.png',
#  'cropped_test_1208.png',
#  'cropped_test_1209.png',
#  'cropped_test_121.png',
#  'cropped_test_1210.png',
#  'cropped_test_1211.png',
#  'cropped_test_1212.png',
#  'cropped_test_1213.png',
#  'cropped_test_1214.png',
#  'cropped_test_1215.png',
#  'cropped_test_1216.png',
#  'cropped_test_1217.png',
#  'cropped_test_1218.png',
#  'cropped_test_1219.png',
#  'cropped_test_122.png',
#  'cropped_test_1220.png',
#  'cropped_test_1221.png',
#  'cropped_test_1222.png',
#  'cropped_test_1223.png',
#  'cropped_test_1224.png',
#  'cropped_test_1225.png',
#  'cropped_test_1226.png',
#  'cropped_test_1227.png',
#  'cropped_test_1228.png',
#  'cropped_test_1229.png',
#  'cropped_test_123.png',
#  'cropped_test_1230.png',
#  'cropped_test_1231.png',
#  'cropped_test_1232.png',
#  'cropped_test_1233.png',
#  'cropped_test_1234.png',
#  'cropped_test_1235.png',
#  'cropped_test_1236.png',
#  'cropped_test_1237.png',
#  'cropped_test_1238.png',
#  'cropped_test_1239.png',
#  'cropped_test_124.png',
#  'cropped_test_1240.png',
#  'cropped_test_1241.png',
#  'cropped_test_1242.png',
#  'cropped_test_1243.png',
#  'cropped_test_1244.png',
#  'cropped_test_1245.png',
#  'cropped_test_1246.png',
#  'cropped_test_1247.png',
#  'cropped_test_1248.png',
#  'cropped_test_1249.png',
#  'cropped_test_125.png',
#  'cropped_test_1250.png',
#  'cropped_test_1251.png',
#  'cropped_test_1252.png',
#  'cropped_test_1253.png',
#  'cropped_test_1254.png',
#  'cropped_test_1255.png',
#  'cropped_test_1256.png',
#  'cropped_test_1257.png',
#  'cropped_test_1258.png',
#  'cropped_test_1259.png',
#  'cropped_test_126.png',
#  'cropped_test_1260.png',
#  'cropped_test_1261.png',
#  'cropped_test_1262.png',
#  'cropped_test_1263.png',
#  'cropped_test_1264.png',
#  'cropped_test_1265.png',
#  'cropped_test_1266.png',
#  'cropped_test_1267.png',
#  'cropped_test_1268.png',
#  'cropped_test_1269.png',
#  'cropped_test_127.png',
#  'cropped_test_1270.png',
#  'cropped_test_1271.png',
#  'cropped_test_1272.png',
#  'cropped_test_1273.png',
#  'cropped_test_1274.png',
#  'cropped_test_1275.png',
#  'cropped_test_1276.png',
#  'cropped_test_1277.png',
#  'cropped_test_1278.png',
#  'cropped_test_1279.png',
#  'cropped_test_128.png',
#  'cropped_test_1280.png',
#  'cropped_test_1281.png',
#  'cropped_test_1282.png',
#  'cropped_test_1283.png',
#  'cropped_test_1284.png',
#  'cropped_test_1285.png',
#  'cropped_test_1286.png',
#  'cropped_test_1287.png',
#  'cropped_test_1288.png',
#  'cropped_test_1289.png',
#  'cropped_test_129.png',
#  'cropped_test_1290.png',
#  'cropped_test_1291.png',
#  'cropped_test_1292.png',
#  'cropped_test_1293.png',
#  'cropped_test_1294.png',
#  'cropped_test_1295.png',
#  'cropped_test_1296.png',
#  'cropped_test_1297.png',
#  'cropped_test_1298.png',
#  'cropped_test_1299.png',
#  'cropped_test_13.png',
#  'cropped_test_130.png',
#  'cropped_test_1300.png',
#  'cropped_test_1301.png',
#  'cropped_test_1302.png',
#  'cropped_test_1303.png',
#  'cropped_test_1304.png',
#  'cropped_test_1305.png',
#  'cropped_test_1306.png',
#  'cropped_test_1307.png',
#  'cropped_test_1308.png',
#  'cropped_test_1309.png',
#  'cropped_test_131.png',
#  'cropped_test_1310.png',
#  'cropped_test_1311.png',
#  'cropped_test_1312.png',
#  'cropped_test_1313.png',
#  'cropped_test_1314.png',
#  'cropped_test_1315.png',
#  'cropped_test_1316.png',
#  'cropped_test_1317.png',
#  'cropped_test_1318.png',
#  'cropped_test_1319.png',
#  'cropped_test_132.png',
#  'cropped_test_1320.png',
#  'cropped_test_1321.png',
#  'cropped_test_1322.png',
#  'cropped_test_1323.png',
#  'cropped_test_1324.png',
#  'cropped_test_1325.png',
#  'cropped_test_1326.png',
#  'cropped_test_1327.png',
#  'cropped_test_1328.png',
#  'cropped_test_1329.png',
#  'cropped_test_133.png',
#  'cropped_test_1330.png',
#  'cropped_test_1331.png',
#  'cropped_test_1332.png',
#  'cropped_test_1333.png',
#  'cropped_test_1334.png',
#  'cropped_test_1335.png',
#  'cropped_test_1336.png',
#  'cropped_test_1337.png',
#  'cropped_test_1338.png',
#  'cropped_test_1339.png',
#  'cropped_test_134.png',
#  'cropped_test_1340.png',
#  'cropped_test_1341.png',
#  'cropped_test_1342.png',
#  'cropped_test_1343.png',
#  'cropped_test_1344.png',
#  'cropped_test_1345.png',
#  'cropped_test_1346.png',
#  'cropped_test_1347.png',
#  'cropped_test_1348.png',
#  'cropped_test_1349.png',
#  'cropped_test_135.png',
#  'cropped_test_1350.png',
#  'cropped_test_1351.png',
#  'cropped_test_1352.png',
#  'cropped_test_1353.png',
#  'cropped_test_1354.png',
#  'cropped_test_1355.png',
#  'cropped_test_1356.png',
#  'cropped_test_1357.png',
#  'cropped_test_1358.png',
#  'cropped_test_1359.png',
#  'cropped_test_136.png',
#  'cropped_test_1360.png',
#  'cropped_test_1361.png',
#  'cropped_test_1362.png',
#  'cropped_test_1363.png',
#  'cropped_test_1364.png',
#  'cropped_test_1365.png',
#  'cropped_test_1366.png',
#  'cropped_test_1367.png',
#  'cropped_test_1368.png',
#  'cropped_test_1369.png',
#  'cropped_test_137.png',
#  'cropped_test_1370.png',
#  'cropped_test_1371.png',
#  'cropped_test_1372.png',
#  'cropped_test_1373.png',
#  'cropped_test_1374.png',
#  'cropped_test_1375.png',
#  'cropped_test_1376.png',
#  'cropped_test_1377.png',
#  'cropped_test_1378.png',
#  'cropped_test_1379.png',
#  'cropped_test_138.png',
#  'cropped_test_1380.png',
#  'cropped_test_1381.png',
#  'cropped_test_1382.png',
#  'cropped_test_1383.png',
#  'cropped_test_1384.png',
#  'cropped_test_1385.png',
#  'cropped_test_1386.png',
#  'cropped_test_1387.png',
#  'cropped_test_1388.png',
#  'cropped_test_1389.png',
#  'cropped_test_139.png',
#  'cropped_test_1390.png',
#  'cropped_test_1391.png',
#  'cropped_test_1392.png',
#  'cropped_test_1393.png',
#  'cropped_test_1394.png',
#  'cropped_test_1395.png',
#  'cropped_test_1396.png',
#  'cropped_test_1397.png',
#  'cropped_test_1398.png',
#  'cropped_test_1399.png',
#  'cropped_test_14.png',
#  'cropped_test_140.png',
#  'cropped_test_1400.png',
#  'cropped_test_1401.png',
#  'cropped_test_1402.png',
#  'cropped_test_1403.png',
#  'cropped_test_1404.png',
#  'cropped_test_1405.png',
#  'cropped_test_1406.png',
#  'cropped_test_1407.png',
#  'cropped_test_1408.png',
#  'cropped_test_1409.png',
#  'cropped_test_141.png',
#  'cropped_test_1410.png',
#  'cropped_test_1411.png',
#  'cropped_test_1412.png',
#  'cropped_test_1413.png',
#  'cropped_test_1414.png',
#  'cropped_test_1415.png',
#  'cropped_test_1416.png',
#  'cropped_test_1417.png',
#  'cropped_test_1418.png',
#  'cropped_test_1419.png',
#  'cropped_test_142.png',
#  'cropped_test_1420.png',
#  'cropped_test_1421.png',
#  'cropped_test_1422.png',
#  'cropped_test_1423.png',
#  'cropped_test_1424.png',
#  'cropped_test_1425.png',
#  'cropped_test_1426.png',
#  'cropped_test_1427.png',
#  'cropped_test_1428.png',
#  'cropped_test_1429.png',
#  'cropped_test_143.png',
#  'cropped_test_1430.png',
#  'cropped_test_1431.png',
#  'cropped_test_1432.png',
#  'cropped_test_1433.png',
#  'cropped_test_1434.png',
#  'cropped_test_1435.png',
#  'cropped_test_1436.png',
#  'cropped_test_1437.png',
#  'cropped_test_1438.png',
#  'cropped_test_1439.png',
#  'cropped_test_144.png',
#  'cropped_test_1440.png',
#  'cropped_test_1441.png',
#  'cropped_test_1442.png',
#  'cropped_test_1443.png',
#  'cropped_test_1444.png',
#  'cropped_test_1445.png',
#  'cropped_test_1446.png',
#  'cropped_test_1447.png',
#  'cropped_test_1448.png',
#  'cropped_test_1449.png',
#  'cropped_test_145.png',
#  'cropped_test_1450.png',
#  'cropped_test_1451.png',
#  'cropped_test_1452.png',
#  'cropped_test_1453.png',
#  'cropped_test_1454.png',
#  'cropped_test_1455.png',
#  'cropped_test_1456.png',
#  'cropped_test_1457.png',
#  'cropped_test_1458.png',
#  'cropped_test_1459.png',
#  'cropped_test_146.png',
#  'cropped_test_1460.png',
#  'cropped_test_1461.png',
#  'cropped_test_1462.png',
#  'cropped_test_1463.png',
#  'cropped_test_1464.png',
#  'cropped_test_1465.png',
#  'cropped_test_1466.png',
#  'cropped_test_1467.png',
#  'cropped_test_1468.png',
#  'cropped_test_1469.png',
#  'cropped_test_147.png',
#  'cropped_test_1470.png',
#  'cropped_test_1471.png',
#  'cropped_test_1472.png',
#  'cropped_test_1473.png',
#  'cropped_test_1474.png',
#  'cropped_test_1475.png',
#  'cropped_test_1476.png',
#  'cropped_test_1477.png',
#  'cropped_test_1478.png',
#  'cropped_test_1479.png',
#  'cropped_test_148.png',
#  'cropped_test_1480.png',
#  'cropped_test_1481.png',
#  'cropped_test_1482.png',
#  'cropped_test_1483.png',
#  'cropped_test_1484.png',
#  'cropped_test_1485.png',
#  'cropped_test_1486.png',
#  'cropped_test_1487.png',
#  'cropped_test_1488.png',
#  'cropped_test_1489.png',
#  'cropped_test_149.png',
#  'cropped_test_1490.png',
#  'cropped_test_1491.png',
#  'cropped_test_1492.png',
#  'cropped_test_1493.png',
#  'cropped_test_1494.png',
#  'cropped_test_1495.png',
#  'cropped_test_1496.png',
#  'cropped_test_1497.png',
#  'cropped_test_1498.png',
#  'cropped_test_1499.png',
#  'cropped_test_15.png',
#  'cropped_test_150.png',
#  'cropped_test_1500.png',
#  'cropped_test_1501.png',
#  'cropped_test_1502.png',
#  'cropped_test_1503.png',
#  'cropped_test_1504.png',
#  'cropped_test_1505.png',
#  'cropped_test_1506.png',
#  'cropped_test_1507.png',
#  'cropped_test_1508.png',
#  'cropped_test_1509.png',
#  'cropped_test_151.png',
#  'cropped_test_1510.png',
#  'cropped_test_1511.png',
#  'cropped_test_1512.png',
#  'cropped_test_1513.png',
#  'cropped_test_1514.png',
#  'cropped_test_1515.png',
#  'cropped_test_1516.png',
#  'cropped_test_1517.png',
#  'cropped_test_1518.png',
#  'cropped_test_1519.png',
#  'cropped_test_152.png',
#  'cropped_test_1520.png',
#  'cropped_test_1521.png',
#  'cropped_test_1522.png',
#  'cropped_test_1523.png',
#  'cropped_test_1524.png',
#  'cropped_test_1525.png',
#  'cropped_test_1526.png',
#  'cropped_test_1527.png',
#  'cropped_test_1528.png',
#  'cropped_test_1529.png',
#  'cropped_test_153.png',
#  'cropped_test_1530.png',
#  'cropped_test_1531.png',
#  'cropped_test_1532.png',
#  'cropped_test_1533.png',
#  'cropped_test_1534.png',
#  'cropped_test_1535.png',
#  'cropped_test_1536.png',
#  'cropped_test_1537.png',
#  'cropped_test_1538.png',
#  'cropped_test_1539.png',
#  'cropped_test_154.png',
#  'cropped_test_1540.png',
#  'cropped_test_1541.png',
#  'cropped_test_1542.png',
#  'cropped_test_1543.png',
#  'cropped_test_1544.png',
#  'cropped_test_1545.png',
#  'cropped_test_1546.png',
#  'cropped_test_1547.png',
#  'cropped_test_1548.png',
#  'cropped_test_1549.png',
#  'cropped_test_155.png',
#  'cropped_test_1550.png',
#  'cropped_test_1551.png',
#  'cropped_test_1552.png',
#  'cropped_test_1553.png',
#  'cropped_test_1554.png',
#  'cropped_test_1555.png',
#  'cropped_test_1556.png',
#  'cropped_test_1557.png',
#  'cropped_test_1558.png',
#  'cropped_test_1559.png',
#  'cropped_test_156.png',
#  'cropped_test_1560.png',
#  'cropped_test_1561.png',
#  'cropped_test_1562.png',
#  'cropped_test_1563.png',
#  'cropped_test_1564.png',
#  'cropped_test_1565.png',
#  'cropped_test_1566.png',
#  'cropped_test_1567.png',
#  'cropped_test_1568.png',
#  'cropped_test_1569.png',
#  'cropped_test_157.png',
#  'cropped_test_1570.png',
#  'cropped_test_1571.png',
#  'cropped_test_1572.png',
#  'cropped_test_1573.png',
#  'cropped_test_1574.png',
#  'cropped_test_1575.png',
#  'cropped_test_1576.png',
#  'cropped_test_1577.png',
#  'cropped_test_1578.png',
#  'cropped_test_1579.png',
#  'cropped_test_158.png',
#  'cropped_test_1580.png',
#  'cropped_test_1581.png',
#  'cropped_test_1582.png',
#  'cropped_test_1583.png',
#  'cropped_test_1584.png',
#  'cropped_test_1585.png',
#  'cropped_test_1586.png',
#  'cropped_test_1587.png',
#  'cropped_test_1588.png',
#  'cropped_test_1589.png',
#  'cropped_test_159.png',
#  'cropped_test_1590.png',
#  'cropped_test_1591.png',
#  'cropped_test_1592.png',
#  'cropped_test_1593.png',
#  'cropped_test_1594.png',
#  'cropped_test_1595.png',
#  'cropped_test_1596.png',
#  'cropped_test_1597.png',
#  'cropped_test_1598.png',
#  'cropped_test_1599.png',
#  'cropped_test_16.png',
#  'cropped_test_160.png',
#  'cropped_test_1600.png',
#  'cropped_test_1601.png',
#  'cropped_test_1602.png',
#  'cropped_test_1603.png',
#  'cropped_test_1604.png',
#  'cropped_test_1605.png',
#  'cropped_test_1606.png',
#  'cropped_test_1607.png',
#  'cropped_test_1608.png',
#  'cropped_test_1609.png',
#  'cropped_test_161.png',
#  'cropped_test_1610.png',
#  'cropped_test_1611.png',
#  'cropped_test_1612.png',
#  'cropped_test_1613.png',
#  'cropped_test_1614.png',
#  'cropped_test_1615.png',
#  'cropped_test_1616.png',
#  'cropped_test_1617.png',
#  'cropped_test_1618.png',
#  'cropped_test_1619.png',
#  'cropped_test_162.png',
#  'cropped_test_1620.png',
#  'cropped_test_1621.png',
#  'cropped_test_1622.png',
#  'cropped_test_1623.png',
#  'cropped_test_1624.png',
#  'cropped_test_1625.png',
#  'cropped_test_1626.png',
#  'cropped_test_1627.png',
#  'cropped_test_1628.png',
#  'cropped_test_1629.png',
#  'cropped_test_163.png',
#  'cropped_test_1630.png',
#  'cropped_test_1631.png',
#  'cropped_test_1632.png',
#  'cropped_test_1633.png',
#  'cropped_test_1634.png',
#  'cropped_test_1635.png',
#  'cropped_test_1636.png',
#  'cropped_test_1637.png',
#  'cropped_test_1638.png',
#  'cropped_test_1639.png',
#  'cropped_test_164.png',
#  'cropped_test_1640.png',
#  'cropped_test_1641.png',
#  'cropped_test_1642.png',
#  'cropped_test_1643.png',
#  'cropped_test_1644.png',
#  'cropped_test_1645.png',
#  'cropped_test_1646.png',
#  'cropped_test_1647.png',
#  'cropped_test_1648.png',
#  'cropped_test_1649.png',
#  'cropped_test_165.png',
#  'cropped_test_1650.png',
#  'cropped_test_1651.png',
#  'cropped_test_1652.png',
#  'cropped_test_1653.png',
#  'cropped_test_1654.png',
#  'cropped_test_1655.png',
#  'cropped_test_1656.png',
#  'cropped_test_1657.png',
#  'cropped_test_1658.png',
#  'cropped_test_1659.png',
#  'cropped_test_166.png',
#  'cropped_test_1660.png',
#  'cropped_test_1661.png',
#  'cropped_test_1662.png',
#  'cropped_test_1663.png',
#  'cropped_test_1664.png',
#  'cropped_test_1665.png',
#  'cropped_test_1666.png',
#  'cropped_test_1667.png',
#  'cropped_test_1668.png',
#  'cropped_test_1669.png',
#  'cropped_test_167.png',
#  'cropped_test_1670.png',
#  'cropped_test_1671.png',
#  'cropped_test_1672.png',
#  'cropped_test_1673.png',
#  'cropped_test_1674.png',
#  'cropped_test_1675.png',
#  'cropped_test_1676.png',
#  'cropped_test_1677.png',
#  'cropped_test_1678.png',
#  'cropped_test_1679.png',
#  'cropped_test_168.png',
#  'cropped_test_1680.png',
#  'cropped_test_1681.png',
#  'cropped_test_1682.png',
#  'cropped_test_1683.png',
#  'cropped_test_1684.png',
#  'cropped_test_1685.png',
#  'cropped_test_1686.png',
#  'cropped_test_1687.png',
#  'cropped_test_1688.png',
#  'cropped_test_1689.png',
#  'cropped_test_169.png',
#  'cropped_test_1690.png',
#  'cropped_test_1691.png',
#  'cropped_test_1692.png',
#  'cropped_test_1693.png',
#  'cropped_test_1694.png',
#  'cropped_test_1695.png',
#  'cropped_test_1696.png',
#  'cropped_test_1697.png',
#  'cropped_test_1698.png',
#  'cropped_test_1699.png',
#  'cropped_test_17.png',
#  'cropped_test_170.png',
#  'cropped_test_1700.png',
#  'cropped_test_1701.png',
#  'cropped_test_1702.png',
#  'cropped_test_1703.png',
#  'cropped_test_1704.png',
#  'cropped_test_1705.png',
#  'cropped_test_1706.png',
#  'cropped_test_1707.png',
#  'cropped_test_1708.png',
#  'cropped_test_1709.png',
#  'cropped_test_171.png',
#  'cropped_test_1710.png',
#  'cropped_test_1711.png',
#  'cropped_test_1712.png',
#  'cropped_test_1713.png',
#  'cropped_test_1714.png',
#  'cropped_test_1715.png',
#  'cropped_test_1716.png',
#  'cropped_test_1717.png',
#  'cropped_test_1718.png',
#  'cropped_test_1719.png',
#  'cropped_test_172.png',
#  'cropped_test_1720.png',
#  'cropped_test_1721.png',
#  'cropped_test_1722.png',
#  'cropped_test_1723.png',
#  'cropped_test_1724.png',
#  'cropped_test_1725.png',
#  'cropped_test_1726.png',
#  'cropped_test_1727.png',
#  'cropped_test_1728.png',
#  'cropped_test_1729.png',
#  'cropped_test_173.png',
#  'cropped_test_1730.png',
#  'cropped_test_1731.png',
#  'cropped_test_1732.png',
#  'cropped_test_1733.png',
#  'cropped_test_1734.png',
#  'cropped_test_1735.png',
#  'cropped_test_1736.png',
#  'cropped_test_1737.png',
#  'cropped_test_1738.png',
#  'cropped_test_1739.png',
#  'cropped_test_174.png',
#  'cropped_test_1740.png',
#  'cropped_test_1741.png',
#  'cropped_test_1742.png',
#  'cropped_test_1743.png',
#  'cropped_test_1744.png',
#  'cropped_test_1745.png',
#  'cropped_test_1746.png',
#  'cropped_test_1747.png',
#  'cropped_test_1748.png',
#  'cropped_test_1749.png',
#  'cropped_test_175.png',
#  'cropped_test_1750.png',
#  'cropped_test_1751.png',
#  'cropped_test_1752.png',
#  'cropped_test_1753.png',
#  'cropped_test_1754.png',
#  'cropped_test_1755.png',
#  'cropped_test_1756.png',
#  'cropped_test_1757.png',
#  'cropped_test_1758.png',
#  'cropped_test_1759.png',
#  'cropped_test_176.png',
#  'cropped_test_1760.png',
#  'cropped_test_1761.png',
#  'cropped_test_1762.png',
#  'cropped_test_1763.png',
#  'cropped_test_1764.png',
#  'cropped_test_1765.png',
#  'cropped_test_1766.png',
#  'cropped_test_1767.png',
#  'cropped_test_1768.png',
#  'cropped_test_1769.png',
#  'cropped_test_177.png',
#  'cropped_test_1770.png',
#  'cropped_test_1771.png',
#  'cropped_test_1772.png',
#  'cropped_test_1773.png',
#  'cropped_test_1774.png',
#  'cropped_test_1775.png',
#  'cropped_test_1776.png',
#  'cropped_test_1777.png',
#  'cropped_test_1778.png',
#  'cropped_test_1779.png',
#  'cropped_test_178.png',
#  'cropped_test_1780.png',
#  'cropped_test_1781.png',
#  'cropped_test_1782.png',
#  'cropped_test_1783.png',
#  'cropped_test_1784.png',
#  'cropped_test_1785.png',
#  'cropped_test_1786.png',
#  'cropped_test_1787.png',
#  'cropped_test_1788.png',
#  'cropped_test_1789.png',
#  'cropped_test_179.png',
#  'cropped_test_1790.png',
#  'cropped_test_1791.png',
#  'cropped_test_1792.png',
#  'cropped_test_1793.png',
#  'cropped_test_1794.png',
#  'cropped_test_1795.png',
#  'cropped_test_1796.png',
#  'cropped_test_1797.png',
#  'cropped_test_1798.png',
#  'cropped_test_1799.png',
#  'cropped_test_18.png',
#  'cropped_test_180.png',
#  'cropped_test_1800.png',
#  'cropped_test_1801.png',
#  'cropped_test_1802.png',
#  'cropped_test_1803.png',
#  'cropped_test_1804.png',
#  'cropped_test_1805.png',
#  'cropped_test_1806.png',
#  'cropped_test_1807.png',
#  'cropped_test_1808.png',
#  'cropped_test_1809.png',
#  'cropped_test_181.png',
#  'cropped_test_1810.png',
#  'cropped_test_1811.png',
#  'cropped_test_1812.png',
#  'cropped_test_1813.png',
#  'cropped_test_1814.png',
#  'cropped_test_1815.png',
#  'cropped_test_1816.png',
#  'cropped_test_1817.png',
#  'cropped_test_1818.png',
#  'cropped_test_1819.png',
#  'cropped_test_182.png',
#  'cropped_test_1820.png',
#  'cropped_test_1821.png',
#  'cropped_test_1822.png',
#  'cropped_test_1823.png',
#  'cropped_test_1824.png',
#  'cropped_test_1825.png',
#  'cropped_test_1826.png',
#  'cropped_test_1827.png',
#  'cropped_test_1828.png',
#  'cropped_test_1829.png',
#  'cropped_test_183.png',
#  'cropped_test_1830.png',
#  'cropped_test_1831.png',
#  'cropped_test_1832.png',
#  'cropped_test_1833.png',
#  'cropped_test_1834.png',
#  'cropped_test_1835.png',
#  'cropped_test_1836.png',
#  'cropped_test_1837.png',
#  'cropped_test_1838.png',
#  'cropped_test_1839.png',
#  'cropped_test_184.png',
#  'cropped_test_1840.png',
#  'cropped_test_1841.png',
#  'cropped_test_1842.png',
#  'cropped_test_1843.png',
#  'cropped_test_1844.png',
#  'cropped_test_1845.png',
#  'cropped_test_1846.png',
#  'cropped_test_1847.png',
#  'cropped_test_1848.png',
#  'cropped_test_1849.png',
#  'cropped_test_185.png',
#  'cropped_test_1850.png',
#  'cropped_test_1851.png',
#  'cropped_test_1852.png',
#  'cropped_test_1853.png',
#  'cropped_test_1854.png',
#  'cropped_test_1855.png',
#  'cropped_test_1856.png',
#  'cropped_test_1857.png',
#  'cropped_test_1858.png',
#  'cropped_test_1859.png',
#  'cropped_test_186.png',
#  'cropped_test_1860.png',
#  'cropped_test_1861.png',
#  'cropped_test_1862.png',
#  'cropped_test_1863.png',
#  'cropped_test_1864.png',
#  'cropped_test_1865.png',
#  'cropped_test_1866.png',
#  'cropped_test_1867.png',
#  'cropped_test_1868.png',
#  'cropped_test_1869.png',
#  'cropped_test_187.png',
#  'cropped_test_1870.png',
#  'cropped_test_1871.png',
#  'cropped_test_1872.png',
#  'cropped_test_1873.png',
#  'cropped_test_1874.png',
#  'cropped_test_1875.png',
#  'cropped_test_1876.png',
#  'cropped_test_1877.png',
#  'cropped_test_1878.png',
#  'cropped_test_1879.png',
#  'cropped_test_188.png',
#  'cropped_test_1880.png',
#  'cropped_test_1881.png',
#  'cropped_test_1882.png',
#  'cropped_test_1883.png',
#  'cropped_test_1884.png',
#  'cropped_test_1885.png',
#  'cropped_test_1886.png',
#  'cropped_test_1887.png',
#  'cropped_test_1888.png',
#  'cropped_test_1889.png',
#  'cropped_test_189.png',
#  'cropped_test_1890.png',
#  'cropped_test_1891.png',
#  'cropped_test_1892.png',
#  'cropped_test_1893.png',
#  'cropped_test_1894.png',
#  'cropped_test_1895.png',
#  'cropped_test_1896.png',
#  'cropped_test_1897.png',
#  'cropped_test_1898.png',
#  ...]
